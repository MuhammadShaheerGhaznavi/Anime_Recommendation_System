# %%
import numpy  as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\shahe\\OneDrive - HKUST Connect\\Projects\\Anime Recommendation'

# %%
df = pd.read_csv("./dataset.csv/anime.csv")
synopsis = pd.read_csv("./dataset.csv/anime_with_synopsis.csv")

# %%
df.dropna(inplace=True)
synopsis.dropna(inplace=True)
synopsis =synopsis[['Name','sypnopsis']]

# %%
df = df.merge(synopsis, on='Name')

# %%
df = df[['MAL_ID','Name','Genres','sypnopsis','Type','Studios','Rating']]

# %%
df
# Out:
#        MAL_ID                             Name  \
# 0           1                     Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira
# 2           6                           Trigun
# 3           7               Witch Hunter Robin
# 4           8                   Bouken Ou Beet
# ...       ...                              ...
# 16211   48481  Daomu Biji Zhi Qinling Shen Shu
# 16212   48483                     Mieruko-chan
# 16213   48488  Higurashi no Naku Koro ni Sotsu
# 16214   48491      Yama no Susume: Next Summit
# 16215   48492                    Scarlet Nexus
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# 4              Adventure, Fantasy, Shounen, Supernatural
# ...                                                  ...
# 16211                   Adventure, Mystery, Supernatural
# 16212                       Comedy, Horror, Supernatural
# 16213  Mystery, Dementia, Horror, Psychological, Supe...
# 16214                   Adventure, Slice of Life, Comedy
# 16215                                    Action, Fantasy
#
#                                                sypnopsis   Type  \
# 0      In the year 2071, humanity has colonized sever...     TV
# 1      other day, another bounty—such is the life of ...  Movie
# 2      Vash the Stampede is the man with a $$60,000,0...     TV
# 3      ches are individuals with special powers like ...     TV
# 4      It is the dark century and the people are suff...     TV
# ...                                                  ...    ...
# 16211  No synopsis information has been added to this...    ONA
# 16212  ko is a typical high school student whose life...     TV
# 16213          Sequel to Higurashi no Naku Koro ni Gou .     TV
# 16214                          New Yama no Susume anime.     TV
# 16215  Solar calendar year 2020: grotesque organisms ...     TV
#
#               Studios                          Rating
# 0             Sunrise  R - 17+ (violence & profanity)
# 1               Bones  R - 17+ (violence & profanity)
# 2            Madhouse       PG-13 - Teens 13 or older
# 3             Sunrise       PG-13 - Teens 13 or older
# 4      Toei Animation                   PG - Children
# ...               ...                             ...
# 16211         Unknown                         Unknown
# 16212        Passione                         Unknown
# 16213         Unknown  R - 17+ (violence & profanity)
# 16214            8bit       PG-13 - Teens 13 or older
# 16215         Sunrise                         Unknown
#
# [16216 rows x 7 columns]

# %%
counts = df["sypnopsis"].str.contains("No synopsis information has been added to this").sum()
print(counts)
# Out:
# 709

# %%
df = df[~((df['sypnopsis'].str.contains("No synopsis information has been added to this")) & (df['Genres'] == 'Unknown'))]

# %%
df.shape
# Out:
# (16195, 7)

# %%
df
# Out:
#        MAL_ID                             Name  \
# 0           1                     Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira
# 2           6                           Trigun
# 3           7               Witch Hunter Robin
# 4           8                   Bouken Ou Beet
# ...       ...                              ...
# 16211   48481  Daomu Biji Zhi Qinling Shen Shu
# 16212   48483                     Mieruko-chan
# 16213   48488  Higurashi no Naku Koro ni Sotsu
# 16214   48491      Yama no Susume: Next Summit
# 16215   48492                    Scarlet Nexus
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# 4              Adventure, Fantasy, Shounen, Supernatural
# ...                                                  ...
# 16211                   Adventure, Mystery, Supernatural
# 16212                       Comedy, Horror, Supernatural
# 16213  Mystery, Dementia, Horror, Psychological, Supe...
# 16214                   Adventure, Slice of Life, Comedy
# 16215                                    Action, Fantasy
#
#                                                sypnopsis   Type  \
# 0      In the year 2071, humanity has colonized sever...     TV
# 1      other day, another bounty—such is the life of ...  Movie
# 2      Vash the Stampede is the man with a $$60,000,0...     TV
# 3      ches are individuals with special powers like ...     TV
# 4      It is the dark century and the people are suff...     TV
# ...                                                  ...    ...
# 16211  No synopsis information has been added to this...    ONA
# 16212  ko is a typical high school student whose life...     TV
# 16213          Sequel to Higurashi no Naku Koro ni Gou .     TV
# 16214                          New Yama no Susume anime.     TV
# 16215  Solar calendar year 2020: grotesque organisms ...     TV
#
#               Studios                          Rating
# 0             Sunrise  R - 17+ (violence & profanity)
# 1               Bones  R - 17+ (violence & profanity)
# 2            Madhouse       PG-13 - Teens 13 or older
# 3             Sunrise       PG-13 - Teens 13 or older
# 4      Toei Animation                   PG - Children
# ...               ...                             ...
# 16211         Unknown                         Unknown
# 16212        Passione                         Unknown
# 16213         Unknown  R - 17+ (violence & profanity)
# 16214            8bit       PG-13 - Teens 13 or older
# 16215         Sunrise                         Unknown
#
# [16195 rows x 7 columns]

# %%
df_clean = df.replace('Unknown', np.nan)

# %%
df_clean['Genres'] = df_clean['Genres'].fillna('')
df_clean['sypnopsis'] = df_clean['sypnopsis'].fillna('')
df_clean['Rating'] = df_clean['Rating'].fillna('')
df_clean['Type'] = df_clean['Type'].fillna('')
df_clean['Studios'] = df_clean['Studios'].fillna('')

# %%
df_clean['Rating'] = df_clean['Rating'].replace('R - 17+ (violence & profanity)', '17+')
df_clean['Rating'] = df_clean['Rating'].replace('PG-13 - Teens 13 or older', 'PG-13')
df_clean['Rating'] = df_clean['Rating'].replace('PG - Children', 'PG')
df_clean['Rating'] = df_clean['Rating'].replace('G - All Ages', 'G')
df_clean['Rating'] = df_clean['Rating'].replace('R+ - Mild Nudity', 'R+')

# %%
df_clean['Genres'] = df_clean['Genres'].apply(lambda x:x.split(','))
df_clean['sypnopsis'] = df_clean['sypnopsis'].apply(lambda x:x.split())
df_clean['Rating'] = df_clean['Rating'].apply(lambda x:x.split())
df_clean['Type'] = df_clean['Type'].apply(lambda x:x.split())
df_clean['Studios'] = df_clean['Studios'].apply(lambda x:x.split())

# %%
df_clean['Genres'] = df_clean['Genres'].apply(lambda x: [i.replace(" ","") for i in x] )
df_clean['sypnopsis'] = df_clean['sypnopsis'].apply(lambda x: [i.replace(" ","") for i in x] )
df_clean['Rating'] = df_clean['Rating'].apply(lambda x: [i.replace(" ","") for i in x] )
df_clean['Type'] = df_clean['Type'].apply(lambda x: [i.replace(" ","") for i in x] )
df_clean['Studios'] = df_clean['Studios'].apply(lambda x: [i.replace(" ","") for i in x] )

# %%
df_clean
# Out:
#        MAL_ID                             Name  \
# 0           1                     Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira
# 2           6                           Trigun
# 3           7               Witch Hunter Robin
# 4           8                   Bouken Ou Beet
# ...       ...                              ...
# 16211   48481  Daomu Biji Zhi Qinling Shen Shu
# 16212   48483                     Mieruko-chan
# 16213   48488  Higurashi no Naku Koro ni Sotsu
# 16214   48491      Yama no Susume: Next Summit
# 16215   48492                    Scarlet Nexus
#
#                                                   Genres  \
# 0      [Action, Adventure, Comedy, Drama, Sci-Fi, Space]
# 1                [Action, Drama, Mystery, Sci-Fi, Space]
# 2      [Action, Sci-Fi, Adventure, Comedy, Drama, Sho...
# 3      [Action, Mystery, Police, Supernatural, Drama,...
# 4            [Adventure, Fantasy, Shounen, Supernatural]
# ...                                                  ...
# 16211                 [Adventure, Mystery, Supernatural]
# 16212                     [Comedy, Horror, Supernatural]
# 16213  [Mystery, Dementia, Horror, Psychological, Sup...
# 16214                   [Adventure, SliceofLife, Comedy]
# 16215                                  [Action, Fantasy]
#
#                                                sypnopsis     Type  \
# 0      [In, the, year, 2071,, humanity, has, colonize...     [TV]
# 1      [other, day,, another, bounty—such, is, the, l...  [Movie]
# 2      [Vash, the, Stampede, is, the, man, with, a, $...     [TV]
# 3      [ches, are, individuals, with, special, powers...     [TV]
# 4      [It, is, the, dark, century, and, the, people,...     [TV]
# ...                                                  ...      ...
# 16211  [No, synopsis, information, has, been, added, ...    [ONA]
# 16212  [ko, is, a, typical, high, school, student, wh...     [TV]
# 16213  [Sequel, to, Higurashi, no, Naku, Koro, ni, Go...     [TV]
# 16214                    [New, Yama, no, Susume, anime.]     [TV]
# 16215  [Solar, calendar, year, 2020:, grotesque, orga...     [TV]
#
#                  Studios   Rating
# 0              [Sunrise]    [17+]
# 1                [Bones]    [17+]
# 2             [Madhouse]  [PG-13]
# 3              [Sunrise]  [PG-13]
# 4      [Toei, Animation]     [PG]
# ...                  ...      ...
# 16211                 []       []
# 16212         [Passione]       []
# 16213                 []    [17+]
# 16214             [8bit]  [PG-13]
# 16215          [Sunrise]       []
#
# [16195 rows x 7 columns]

# %%
df = df_clean
df['tags'] = df['sypnopsis'] +df['Genres'] + df['Rating']+ df['Studios']+df['Type']

# %%
df =df[['MAL_ID', 'Name', 'tags']]

# %%
df['tags'] = df['tags'].apply(lambda x: ' '.join(x) )
df['tags'] =df['tags'].apply(lambda x: x.lower())

# %%
df['tags'][0]
# Out:
# 'in the year 2071, humanity has colonized several of the planets and moons of the solar system leaving the now uninhabitable surface of planet earth behind. the inter solar system police attempts to keep peace in the galaxy, aided in part by outlaw bounty hunters, referred to as "cowboys." the ragtag team aboard the spaceship bebop are two such individuals. mellow and carefree spike spiegel is balanced by his boisterous, pragmatic partner jet black as the pair makes a living chasing bounties and collecting rewards. thrown off course by the addition of new members that they meet in their travels—ein, a genetically engineered, highly intelligent welsh corgi; femme fatale faye valentine, an enigmatic trickster with memory loss; and the strange computer whiz kid edward wong—the crew embarks on thrilling adventures that unravel each member\'s dark and mysterious past little by little. well-balanced with high density action and light-hearted comedy, cowboy bebop is a space western classic and an homage to the smooth and improvised music it is named after. action adventure comedy drama sci-fi space 17+ sunrise tv'
